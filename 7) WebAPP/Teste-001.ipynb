# %% [markdown]
# # Nova seção

# %%
# !pip install jupyter-dash

# %%
# !pip install streamlit -q

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

# %%
# Tabela ja vem no plotly.express
df = px.data.tips()

# %%
# Criando o app
app = JupyterDash(__name__,external_stylesheets=external_stylesheets)

app.layout = html.Div([
    html.H1("App de teste com ngrok"),
    dcc.Graph(id='graph'),
    html.Label([
        "colorscale",
        dcc.Dropdown(
            id='colorscale-dropdown',
            clearable=False, value='plasma',
            options=[
                {'label': c, 'value': c}
                for c in px.colors.named_colorscales()
            ])
    ]),
])

# %%
@app.callback(
    Output('graph', 'figure'),
    [Input("colorscale-dropdown", "value")
])

def update_figure(colorscale):
  return px.scatter(
      df, x="total_bill", y="tip", color="size",
      color_continuous_scale=colorscale,
      render_mode="webgl", title="Tips"
  )

# %%
app.run_server(mode='external')

# %% [markdown]
# # TENTATIVAS

# %%
# =========================================================================================

# %%
# !pip install pyngrok
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (6.0.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0)

# %%
! ngrok authtoken 2Squm2vrfva7ltUfDmOkSgamXyd_25rD9FbrSrpW9Uw4KDRhZ
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
from pyngrok import ngrok
ngrok.set_auth_token ("2Squm2vrfva7ltUfDmOkSgamXyd_25rD9FbrSrpW9Uw4KDRhZ")
# !nohup streamlit run app.py --server.port 80 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
public_url = ngrok.connect('80')
public_url
# Out:
# <NgrokTunnel: "https://4bba-34-75-9-84.ngrok-free.app" -> "http://localhost:80">

# %%
# !ngrok http 80

# %%
# %%writefile app.py
import streamlit as st
st.write('# Hello wold')
st.write('## Run Server')
st.write('### Eu te amo Misma')
# Out:
# Overwriting app.py
